# %% [markdown]
# # Lab 02: The Design Loop (The Scissors Gap)
# The asymmetry between AI generation (seconds) and physical verification (weeks).

# %%
import time
import json
import sys

print("LLM generating hardware RTL...", flush=True)
time.sleep(1)
print("Generation complete in 1 second!\n", flush=True)

print("Sending RTL to physical OpenROAD Place & Route...\n[WARN] High density detected...", flush=True)
for i in range(1, 10):
    print(f"Routing iteration {i}... congestion at 34%", flush=True)
    time.sleep(0.5)
print("\n[FATAL] Verification failed after 3 weeks (simulated). Timing constraints violated.")

with open('.arch2_state.json', 'r') as f: state = json.load(f)
state['lab02_complete'] = True
with open('.arch2_state.json', 'w') as f: json.dump(state, f)

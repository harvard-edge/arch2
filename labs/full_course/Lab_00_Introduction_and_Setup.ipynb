# %% [markdown]
# # Lab 00: Introduction & Setup
#
# Welcome to the Architecture 2.0 Workshop! This is the first of 12 Colab-compatible notebooks designed to walk you through the theoretical and practical framework of AI-assisted hardware design.
#
# ### Learning Objectives
# - Understand the Colab environment.
# - Initialize the `.arch2_state.json` persistence file.
#
# ## 1. Setup Environment

# %%
# !pip install -q ipywidgets matplotlib pandas

# %% [markdown]
# ## 2. The `.arch2_state.json` Contract
# We use a state file to propagate constraints and decisions between labs. Run the cell below to initialize it.

# %%
import json
import os

state = {
    'student_name': 'Architect',
    'tools_available': ['python', 'pandas', 'scale-sim-mock']
}

with open('.arch2_state.json', 'w') as f:
    json.dump(state, f)
print('State initialized successfully!')

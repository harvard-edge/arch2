# %% [markdown]
# # Lab 00: Introduction & Workshop Overview
# Welcome to the Architecture 2.0 Full-Course Workshop!

# %% [markdown]
# ## State Persistence
# All labs share a persistent state file `.arch2_state.json`. You must run the notebooks sequentially so data flows continuously from intent down to physical gates.

# %% [markdown]
# ```mermaid
# flowchart LR
# Intent(Lab 4: YAML) --> AI(Lab 5: LLM)
# AI --> Proxy(Lab 6: SCALE-Sim)
# Proxy --> Yosys(Lab 8: Logic Synth)
# ```
